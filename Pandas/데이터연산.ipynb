# %% [markdown]
# ## 데이터 연산

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randint(0, 10, 5))
s
# Out:
# 0    8
# 1    8
# 2    0
# 3    7
# 4    2
# dtype: int64

# %%
df = pd.DataFrame(np.random.randint(0, 10, (3, 3)),
                  columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  6  6  7
# 1  2  0  7
# 2  6  7  8

# %%
np.exp(s)
# Out:
# 0    2980.957987
# 1    2980.957987
# 2       1.000000
# 3    1096.633158
# 4       7.389056
# dtype: float64

# %%
np.cos(df * np.pi / 4)
# Out:
#               A             B         C
# 0 -1.836970e-16 -1.836970e-16  0.707107
# 1  6.123234e-17  1.000000e+00  0.707107
# 2 -1.836970e-16  7.071068e-01  1.000000

# %%
# index 기준으로 연산됨. index가 없는 것은 NaN으로 출력
s1 = pd.Series([1, 3, 5, 7, 9], index=[0, 1, 2, 3, 4])
s2 = pd.Series([2, 4, 6, 8, 10], index=[1, 2, 3, 4, 5])
s1 + s2
# Out:
# 0     NaN
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5     NaN
# dtype: float64

# %%
# index가 없는 값 0으로 채우고 계산
s1.add(s2, fill_value=0)
# Out:
# 0     1.0
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5    10.0
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randint(0, 20, (3, 3)),
                   columns=list('ACD'))
df1
# Out:
#     A   C   D
# 0  15   9   1
# 1  19   2  16
# 2   0  17   9

# %%
df2 = pd.DataFrame(np.random.randint(0, 20, (5, 5)),
                   columns=list('BAECD'))
df2
# Out:
#     B   A   E   C   D
# 0  17   9  13  15   0
# 1   3  11   3  10   7
# 2   2   2  14  11  16
# 3  11   2  10   4  11
# 4   5  13  16  15  14

# %%
df1 + df2
# Out:
#       A   B     C     D   E
# 0  24.0 NaN  24.0   1.0 NaN
# 1  30.0 NaN  12.0  23.0 NaN
# 2   2.0 NaN  28.0  25.0 NaN
# 3   NaN NaN   NaN   NaN NaN
# 4   NaN NaN   NaN   NaN NaN

# %%
fvalue = df1.stack().mean()
df1.add(df2, fill_value=fvalue)
# Out:
#            A          B          C          D          E
# 0  24.000000  26.777778  24.000000   1.000000  22.777778
# 1  30.000000  12.777778  12.000000  23.000000  12.777778
# 2   2.000000  11.777778  28.000000  25.000000  23.777778
# 3  11.777778  20.777778  13.777778  20.777778  19.777778
# 4  22.777778  14.777778  24.777778  23.777778  25.777778

# %% [markdown]
# ### 연산자 범용 함수

# %% [markdown]
# #### add()

# %%
a = np.random.randint(1, 10, size=(3, 3))
a
# Out:
# array([[9, 7, 5],
#        [3, 8, 9],
#        [9, 2, 4]])

# %%
a + a[0]    # 브로드캐스팅
# Out:
# array([[18, 14, 10],
#        [12, 15, 14],
#        [18,  9,  9]])

# %%
df = pd.DataFrame(a, columns=list('ABC'))
df
# Out:
#    A  B  C
# 0  9  7  5
# 1  3  8  9
# 2  9  2  4

# %%
df + df.iloc[0]
# Out:
#     A   B   C
# 0  18  14  10
# 1  12  15  14
# 2  18   9   9

# %%
df.add(df.iloc[0])    # 판다스가 넘파이를 기반으로 만들어져 연산자, 함수 혼용해서 사용
# Out:
#     A   B   C
# 0  18  14  10
# 1  12  15  14
# 2  18   9   9

# %% [markdown]
# #### sub() / subtract()

# %%
a
# Out:
# array([[9, 7, 5],
#        [3, 8, 9],
#        [9, 2, 4]])

# %%
a - a[0]
# Out:
# array([[ 0,  0,  0],
#        [-6,  1,  4],
#        [ 0, -5, -1]])

# %%
df
# Out:
#    A  B  C
# 0  9  7  5
# 1  3  8  9
# 2  9  2  4

# %%
df - df.iloc[0]
# Out:
#    A  B  C
# 0  0  0  0
# 1 -6  1  4
# 2  0 -5 -1

# %%
df.sub(df.iloc[0])
# Out:
#    A  B  C
# 0  0  0  0
# 1 -6  1  4
# 2  0 -5 -1

# %%
df.subtract(df['B'], axis=0)    # 2차원이므로 축 지정
# Out:
#    A  B  C
# 0  2  0 -2
# 1 -5  0  1
# 2  7  0  2

# %% [markdown]
# #### mul() / multiply()

# %%
a
# Out:
# array([[9, 7, 5],
#        [3, 8, 9],
#        [9, 2, 4]])

# %%
a * a[1]
# Out:
# array([[27, 56, 45],
#        [ 9, 64, 81],
#        [27, 16, 36]])

# %%
df
# Out:
#    A  B  C
# 0  9  7  5
# 1  3  8  9
# 2  9  2  4

# %%
df * df.iloc[1]
# Out:
#     A   B   C
# 0  27  56  45
# 1   9  64  81
# 2  27  16  36

# %%
df.mul(df.iloc[1])
# Out:
#     A   B   C
# 0  27  56  45
# 1   9  64  81
# 2  27  16  36

# %%
df.multiply(df.iloc[1])
# Out:
#     A   B   C
# 0  27  56  45
# 1   9  64  81
# 2  27  16  36

# %% [markdown]
# #### truediv() /  div() / divide() / floordiv()

# %%
a
# Out:
# array([[9, 7, 5],
#        [3, 8, 9],
#        [9, 2, 4]])

# %%
a / a[0]
# Out:
# array([[1.        , 1.        , 1.        ],
#        [0.33333333, 1.14285714, 1.8       ],
#        [1.        , 0.28571429, 0.8       ]])

# %%
df
# Out:
#    A  B  C
# 0  9  7  5
# 1  3  8  9
# 2  9  2  4

# %%
df / df.iloc[0]
# Out:
#           A         B    C
# 0  1.000000  1.000000  1.0
# 1  0.333333  1.142857  1.8
# 2  1.000000  0.285714  0.8

# %%
df.truediv(df.iloc[0])
# Out:
#           A         B    C
# 0  1.000000  1.000000  1.0
# 1  0.333333  1.142857  1.8
# 2  1.000000  0.285714  0.8

# %%
df.div(df.iloc[0])
# Out:
#           A         B    C
# 0  1.000000  1.000000  1.0
# 1  0.333333  1.142857  1.8
# 2  1.000000  0.285714  0.8

# %%
df.divide(df.iloc[0])
# Out:
#           A         B    C
# 0  1.000000  1.000000  1.0
# 1  0.333333  1.142857  1.8
# 2  1.000000  0.285714  0.8

# %%
a // a[0]
# Out:
# array([[1, 1, 1],
#        [0, 1, 1],
#        [1, 0, 0]])

# %%
df.floordiv(df.iloc[0])
# Out:
#    A  B  C
# 0  1  1  1
# 1  0  1  1
# 2  1  0  0

# %% [markdown]
# #### mod()

# %%
a
# Out:
# array([[9, 7, 5],
#        [3, 8, 9],
#        [9, 2, 4]])

# %%
a % a[0]
# Out:
# array([[0, 0, 0],
#        [3, 1, 4],
#        [0, 2, 4]])

# %%
df
# Out:
#    A  B  C
# 0  9  7  5
# 1  3  8  9
# 2  9  2  4

# %%
df.mod(df.iloc[0])
# Out:
#    A  B  C
# 0  0  0  0
# 1  3  1  4
# 2  0  2  4

# %% [markdown]
# #### pow()

# %%
a
# Out:
# array([[9, 7, 5],
#        [3, 8, 9],
#        [9, 2, 4]])

# %%
a ** a[0]
# Out:
# array([[387420489,    823543,      3125],
#        [    19683,   2097152,     59049],
#        [387420489,       128,      1024]])

# %%
df
# Out:
#    A  B  C
# 0  9  7  5
# 1  3  8  9
# 2  9  2  4

# %%
df.pow(df.iloc[0])
# Out:
#            A        B      C
# 0  387420489   823543   3125
# 1      19683  2097152  59049
# 2  387420489      128   1024

# %%
row = df.iloc[0, ::2]
row
# Out:
# A    9
# C    5
# Name: 0, dtype: int64

# %%
df - row    # 선택한 부분(A, C)만 빼기
# Out:
#      A   B    C
# 0  0.0 NaN  0.0
# 1 -6.0 NaN  4.0
# 2  0.0 NaN -1.0

# %% [markdown]
# ### 정렬(Sort)

# %%
s = pd.Series(range(5), index=['A', 'D', 'B', 'C', 'E'])
s
# Out:
# A    0
# D    1
# B    2
# C    3
# E    4
# dtype: int64

# %%
s.sort_index()
# Out:
# A    0
# B    2
# C    3
# D    1
# E    4
# dtype: int64

# %%
s.sort_values()
# Out:
# A    0
# D    1
# B    2
# C    3
# E    4
# dtype: int64

# %%
df = pd.DataFrame(np.random.randint(0, 10, (4, 4)),
                  index=[2, 4, 1, 3],
                  columns=list('BDAC'))
df
# Out:
#    B  D  A  C
# 2  7  5  0  2
# 4  2  5  7  9
# 1  0  1  1  5
# 3  1  5  4  0

# %%
df.sort_index()
# Out:
#    B  D  A  C
# 1  0  1  1  5
# 2  7  5  0  2
# 3  1  5  4  0
# 4  2  5  7  9

# %%
df.sort_index(axis=1)
# Out:
#    A  B  C  D
# 2  0  7  2  5
# 4  7  2  9  5
# 1  1  0  5  1
# 3  4  1  0  5

# %%
df.sort_values(by='A')    # 2차원이므로 기준 정해야 함. A 컬럼 값 기준으로 정렬됨
# Out:
#    B  D  A  C
# 2  7  5  0  2
# 1  0  1  1  5
# 3  1  5  4  0
# 4  2  5  7  9

# %%
df.sort_values(by=['A','C'])
# Out:
#    B  D  A  C
# 2  7  5  0  2
# 1  0  1  1  5
# 3  1  5  4  0
# 4  2  5  7  9

# %% [markdown]
# ### 순위(Ranking)

# %%
s = pd.Series([-2, 4, 7, 3, 0, 7, 5, -4, 2, 6])
s
# Out:
# 0   -2
# 1    4
# 2    7
# 3    3
# 4    0
# 5    7
# 6    5
# 7   -4
# 8    2
# 9    6
# dtype: int64

# %%
s.rank()    # 같은 수가 있는 경우 순위를 .5로 나눠서 나타냄
# Out:
# 0    2.0
# 1    6.0
# 2    9.5
# 3    5.0
# 4    3.0
# 5    9.5
# 6    7.0
# 7    1.0
# 8    4.0
# 9    8.0
# dtype: float64

# %%
s.rank(method='first')    # 같은 수가 있는 경우 먼저 나온 수를 상위로 랭킹
# Out:
# 0     2.0
# 1     6.0
# 2     9.0
# 3     5.0
# 4     3.0
# 5    10.0
# 6     7.0
# 7     1.0
# 8     4.0
# 9     8.0
# dtype: float64

# %%
s.rank(method='max')    # 같은 수가 있는 경우 둘 다 하위로 랭킹
# Out:
# 0     2.0
# 1     6.0
# 2    10.0
# 3     5.0
# 4     3.0
# 5    10.0
# 6     7.0
# 7     1.0
# 8     4.0
# 9     8.0
# dtype: float64

# %% [markdown]
# ### 고성능 연산

# %%
nrows, ncols = 100000, 100
df1, df2, df3, df4 = (pd.DataFrame(np.random.rand(nrows, ncols)) for i in range(4))

# %%
# %timeit df1 + df2 + df3 + df4
# Out:
# 10 loops, best of 5: 59.6 ms per loop

# %%
# %timeit pd.eval('df1 + df2 + df3 + df4')    # 빠른 속도로 연산 수행
# Out:
# 10 loops, best of 5: 41.6 ms per loop

# %%
# %timeit df1 * -df2 / (-df3 * df4)
# Out:
# 10 loops, best of 5: 107 ms per loop

# %%
# %timeit pd.eval('df1 * -df2 / (-df3 * df4)')
# Out:
# 10 loops, best of 5: 51.2 ms per loop

# %%
# %timeit (df1 < df2) & (df2 <= df3) & (df3 != df4)
# Out:
# 10 loops, best of 5: 60.4 ms per loop

# %%
# %timeit pd.eval('(df1 < df2) & (df2 <= df3) & (df3 != df4)')
# Out:
# 10 loops, best of 5: 92.4 ms per loop

# %%
df = pd.DataFrame(np.random.rand(1000000, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.head()
# Out:
#           A         B         C         D         E
# 0  0.377602  0.795581  0.128022  0.927095  0.952023
# 1  0.829837  0.904401  0.765395  0.716236  0.641818
# 2  0.064382  0.780903  0.074593  0.849271  0.432093
# 3  0.717740  0.206640  0.919457  0.098118  0.211042
# 4  0.361087  0.454134  0.092139  0.536303  0.547374

# %%
# %timeit df['A'] + df['B'] / df['C'] -df['D'] * df['E']
# Out:
# 10 loops, best of 5: 20.7 ms per loop

# %%
# %timeit pd.eval('df.A + df.B / df.C -df.D * df.E')
# Out:
# 100 loops, best of 5: 8.33 ms per loop

# %%
# %timeit(df.eval('A + B / C - D * E'))
# Out:
# 100 loops, best of 5: 13 ms per loop

# %%
df.eval('R = A + B / C - D * E', inplace=True)
df.head()
# Out:
#           A         B         C         D         E          R
# 0  0.377602  0.795581  0.128022  0.927095  0.952023   5.709385
# 1  0.829837  0.904401  0.765395  0.716236  0.641818   1.551758
# 2  0.064382  0.780903  0.074593  0.849271  0.432093  10.166288
# 3  0.717740  0.206640  0.919457  0.098118  0.211042   0.921775
# 4  0.361087  0.454134  0.092139  0.536303  0.547374   4.996297

# %%
df.eval('R = A - B / C + D * E', inplace=True)
df.head()
# Out:
#           A         B         C         D         E          R
# 0  0.377602  0.795581  0.128022  0.927095  0.952023  -4.954182
# 1  0.829837  0.904401  0.765395  0.716236  0.641818   0.107916
# 2  0.064382  0.780903  0.074593  0.849271  0.432093 -10.037523
# 3  0.717740  0.206640  0.919457  0.098118  0.211042   0.513705
# 4  0.361087  0.454134  0.092139  0.536303  0.547374  -4.274124

# %%
col_mean = df.mean(1)
df['A'] + col_mean
# Out:
# 0         0.081958
# 1         1.490771
# 2        -1.241664
# 3         1.162190
# 4        -0.019428
#             ...
# 999995    0.670544
# 999996    1.258830
# 999997    1.343470
# 999998    1.095294
# 999999    1.514238
# Length: 1000000, dtype: float64

# %%
df.eval('A + @col_mean')    # @으로 외부 변수에 접근
# Out:
# 0         0.081958
# 1         1.490771
# 2        -1.241664
# 3         1.162190
# 4        -0.019428
#             ...
# 999995    0.670544
# 999996    1.258830
# 999997    1.343470
# 999998    1.095294
# 999999    1.514238
# Length: 1000000, dtype: float64

# %%
df[(df.A < 0.5) & (df.B < 0.5) & (df.C > 0.5)]
# Out:
#                A         B         C         D         E         R
# 5       0.224065  0.122682  0.654769  0.763448  0.493707  0.413618
# 12      0.040334  0.413161  0.975840  0.418697  0.053922 -0.360480
# 14      0.391268  0.228132  0.523002  0.938175  0.188566  0.131978
# 16      0.179296  0.448222  0.893680  0.288426  0.678406 -0.126580
# 17      0.401679  0.286511  0.661606  0.637057  0.976375  0.590632
# ...          ...       ...       ...       ...       ...       ...
# 999987  0.280954  0.405498  0.824981  0.776644  0.563515  0.227081
# 999991  0.487447  0.137172  0.724615  0.050704  0.550480  0.326056
# 999992  0.209815  0.411734  0.544573  0.441876  0.267326 -0.428129
# 999995  0.362032  0.013831  0.769276  0.144247  0.190199  0.371488
# 999998  0.414106  0.458922  0.881978  0.876044  0.832765  0.623313
#
# [124535 rows x 6 columns]

# %%
pd.eval('df[(df.A < 0.5) & (df.B < 0.5) & (df.C > 0.5)]')
# Out:
#                A         B         C         D         E         R
# 5       0.224065  0.122682  0.654769  0.763448  0.493707  0.413618
# 12      0.040334  0.413161  0.975840  0.418697  0.053922 -0.360480
# 14      0.391268  0.228132  0.523002  0.938175  0.188566  0.131978
# 16      0.179296  0.448222  0.893680  0.288426  0.678406 -0.126580
# 17      0.401679  0.286511  0.661606  0.637057  0.976375  0.590632
# ...          ...       ...       ...       ...       ...       ...
# 999987  0.280954  0.405498  0.824981  0.776644  0.563515  0.227081
# 999991  0.487447  0.137172  0.724615  0.050704  0.550480  0.326056
# 999992  0.209815  0.411734  0.544573  0.441876  0.267326 -0.428129
# 999995  0.362032  0.013831  0.769276  0.144247  0.190199  0.371488
# 999998  0.414106  0.458922  0.881978  0.876044  0.832765  0.623313
#
# [124535 rows x 6 columns]

# %%
df.query('A < 0.5 and B < 0.5 and C > 0.5')
# Out:
#                A         B         C         D         E         R
# 5       0.224065  0.122682  0.654769  0.763448  0.493707  0.413618
# 12      0.040334  0.413161  0.975840  0.418697  0.053922 -0.360480
# 14      0.391268  0.228132  0.523002  0.938175  0.188566  0.131978
# 16      0.179296  0.448222  0.893680  0.288426  0.678406 -0.126580
# 17      0.401679  0.286511  0.661606  0.637057  0.976375  0.590632
# ...          ...       ...       ...       ...       ...       ...
# 999987  0.280954  0.405498  0.824981  0.776644  0.563515  0.227081
# 999991  0.487447  0.137172  0.724615  0.050704  0.550480  0.326056
# 999992  0.209815  0.411734  0.544573  0.441876  0.267326 -0.428129
# 999995  0.362032  0.013831  0.769276  0.144247  0.190199  0.371488
# 999998  0.414106  0.458922  0.881978  0.876044  0.832765  0.623313
#
# [124535 rows x 6 columns]

# %%
col_mean = df['D'].mean()
df[(df.A < col_mean) &  (df.B < col_mean)]
# Out:
#                A         B         C         D         E         R
# 4       0.361087  0.454134  0.092139  0.536303  0.547374 -4.274124
# 5       0.224065  0.122682  0.654769  0.763448  0.493707  0.413618
# 12      0.040334  0.413161  0.975840  0.418697  0.053922 -0.360480
# 13      0.422618  0.009301  0.062506  0.615288  0.672384  0.687520
# 14      0.391268  0.228132  0.523002  0.938175  0.188566  0.131978
# ...          ...       ...       ...       ...       ...       ...
# 999990  0.151054  0.247723  0.161361  0.243156  0.316683 -1.307156
# 999991  0.487447  0.137172  0.724615  0.050704  0.550480  0.326056
# 999992  0.209815  0.411734  0.544573  0.441876  0.267326 -0.428129
# 999995  0.362032  0.013831  0.769276  0.144247  0.190199  0.371488
# 999998  0.414106  0.458922  0.881978  0.876044  0.832765  0.623313
#
# [249895 rows x 6 columns]

# %%
df.query('A < @col_mean and B < @col_mean')
# Out:
#                A         B         C         D         E         R
# 4       0.361087  0.454134  0.092139  0.536303  0.547374 -4.274124
# 5       0.224065  0.122682  0.654769  0.763448  0.493707  0.413618
# 12      0.040334  0.413161  0.975840  0.418697  0.053922 -0.360480
# 13      0.422618  0.009301  0.062506  0.615288  0.672384  0.687520
# 14      0.391268  0.228132  0.523002  0.938175  0.188566  0.131978
# ...          ...       ...       ...       ...       ...       ...
# 999990  0.151054  0.247723  0.161361  0.243156  0.316683 -1.307156
# 999991  0.487447  0.137172  0.724615  0.050704  0.550480  0.326056
# 999992  0.209815  0.411734  0.544573  0.441876  0.267326 -0.428129
# 999995  0.362032  0.013831  0.769276  0.144247  0.190199  0.371488
# 999998  0.414106  0.458922  0.881978  0.876044  0.832765  0.623313
#
# [249895 rows x 6 columns]
