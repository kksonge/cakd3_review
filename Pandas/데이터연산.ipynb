# %% [markdown]
# ## 데이터 연산

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randint(0, 10, 5))
s
# Out:
# 0    9
# 1    2
# 2    4
# 3    6
# 4    5
# dtype: int64

# %%
df = pd.DataFrame(np.random.randint(0, 10, (3, 3)),
                  columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  4  7  0
# 1  9  1  5
# 2  0  3  7

# %%
np.exp(s)
# Out:
# 0    8103.083928
# 1       7.389056
# 2      54.598150
# 3     403.428793
# 4     148.413159
# dtype: float64

# %%
np.cos(df * np.pi / 4)
# Out:
#           A         B         C
# 0 -1.000000  0.707107  1.000000
# 1  0.707107  0.707107 -0.707107
# 2  1.000000 -0.707107  0.707107

# %%
# index 기준으로 연산됨. index가 없는 것은 NaN으로 출력
s1 = pd.Series([1, 3, 5, 7, 9], index=[0, 1, 2, 3, 4])
s2 = pd.Series([2, 4, 6, 8, 10], index=[1, 2, 3, 4, 5])
s1 + s2
# Out:
# 0     NaN
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5     NaN
# dtype: float64

# %%
# index가 없는 값 0으로 채우고 계산
s1.add(s2, fill_value=0)
# Out:
# 0     1.0
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5    10.0
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randint(0, 20, (3, 3)),
                   columns=list('ACD'))
df1
# Out:
#    A   C   D
# 0  7  19   2
# 1  4   2   8
# 2  8  19  14

# %%
df2 = pd.DataFrame(np.random.randint(0, 20, (5, 5)),
                   columns=list('BAECD'))
df2
# Out:
#     B  A   E   C   D
# 0  10  3   4   3  19
# 1  14  6   3   7   7
# 2  19  3  10   9  11
# 3   3  3   2  11   0
# 4  11  2   4  18  15

# %%
df1 + df2
# Out:
#       A   B     C     D   E
# 0  10.0 NaN  22.0  21.0 NaN
# 1  10.0 NaN   9.0  15.0 NaN
# 2  11.0 NaN  28.0  25.0 NaN
# 3   NaN NaN   NaN   NaN NaN
# 4   NaN NaN   NaN   NaN NaN

# %%
fvalue = df1.stack().mean()
df1.add(df2, fill_value=fvalue)
# Out:
#            A          B          C          D          E
# 0  10.000000  19.222222  22.000000  21.000000  13.222222
# 1  10.000000  23.222222   9.000000  15.000000  12.222222
# 2  11.000000  28.222222  28.000000  25.000000  19.222222
# 3  12.222222  12.222222  20.222222   9.222222  11.222222
# 4  11.222222  20.222222  27.222222  24.222222  13.222222

# %% [markdown]
# ### 연산자 범용 함수
