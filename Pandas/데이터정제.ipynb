# %% [markdown]
# ### 누락값 처리
#
#
# *   대부분의 실제 데이터들은 정제되지 않고 누락값들이 존재
# *   서로 다른 데이터들은 다른 형태의 결측을 가짐
# *   결측 데이터는 null, NaN, NA로 표기

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### None: 파이썬 누락 데이터

# %%
a = np.array([1, 2, None, 4, 5])
a
# Out:
# array([1, 2, None, 4, 5], dtype=object)

# %%
# a.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-393d3db239ee> in <module>()
# ----> 1 a.sum()
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# #### NaN: 누락된 수치 데이터

# %%
a = np.array([1, 2, np.nan, 4, 5])
a.dtype
# Out:
# dtype('float64')

# %%
0 + np.nan
# Out:
# nan

# %%
np.nan + np.nan
# Out:
# nan

# %%
a.sum(), a.min(), a.max()
# Out:
# (nan, nan, nan)

# %%
np.nansum(a), np.nanmin(a), np.nanmax(a)
# Out:
# (12.0, 1.0, 5.0)

# %%
pd.Series([1, 2, np.nan, 4, None])
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    NaN
# dtype: float64

# %%
s = pd.Series(range(5), dtype=int)
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
s[0] = None
s
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3    3.0
# 4    4.0
# dtype: float64

# %%
s[3] = np.nan

# %%
s = pd.Series([True, False, None, np.nan])
s
# Out:
# 0     True
# 1    False
# 2     None
# 3      NaN
# dtype: object

# %% [markdown]
# #### Null 값 처리

# %%
s = pd.Series([1, 2, np.nan, 'String', None])
s
# Out:
# 0         1
# 1         2
# 2       NaN
# 3    String
# 4      None
# dtype: object

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
s[s.notnull()]
# Out:
# 0         1
# 1         2
# 3    String
# dtype: object

# %%
s.dropna()
# Out:
# 0         1
# 1         2
# 3    String
# dtype: object

# %%
df = pd.DataFrame({'a':np.random.randn(100),
                   'b':np.random.randn(100),
                   'c':np.random.randn(100)})
df
# Out:
#            a         b         c
# 0   0.565959  0.938298 -0.488098
# 1  -0.904615  1.607846 -0.858925
# 2   0.000982 -0.927009 -0.280384
# 3  -1.900124  0.695701  0.345090
# 4  -0.494950  0.396584  0.546067
# ..       ...       ...       ...
# 95 -1.626816 -1.660603 -0.170808
# 96 -1.097631  0.630780 -0.102535
# 97  0.340152  0.885809  0.395879
# 98 -0.066972 -0.047738 -0.778017
# 99  0.413979 -1.104727 -0.642853
#
# [100 rows x 3 columns]

# %%
df.dropna(axis='columns')
# Out:
#            a         b         c
# 0   0.565959  0.938298 -0.488098
# 1  -0.904615  1.607846 -0.858925
# 2   0.000982 -0.927009 -0.280384
# 3  -1.900124  0.695701  0.345090
# 4  -0.494950  0.396584  0.546067
# ..       ...       ...       ...
# 95 -1.626816 -1.660603 -0.170808
# 96 -1.097631  0.630780 -0.102535
# 97  0.340152  0.885809  0.395879
# 98 -0.066972 -0.047738 -0.778017
# 99  0.413979 -1.104727 -0.642853
#
# [100 rows x 3 columns]

# %%
df[3] = np.nan
df
# Out:
#            a         b         c   3
# 0   0.565959  0.938298 -0.488098 NaN
# 1  -0.904615  1.607846 -0.858925 NaN
# 2   0.000982 -0.927009 -0.280384 NaN
# 3  -1.900124  0.695701  0.345090 NaN
# 4  -0.494950  0.396584  0.546067 NaN
# ..       ...       ...       ...  ..
# 95 -1.626816 -1.660603 -0.170808 NaN
# 96 -1.097631  0.630780 -0.102535 NaN
# 97  0.340152  0.885809  0.395879 NaN
# 98 -0.066972 -0.047738 -0.778017 NaN
# 99  0.413979 -1.104727 -0.642853 NaN
#
# [100 rows x 4 columns]

# %%
df.dropna(axis='columns', how='all')
# Out:
#            a         b         c
# 0   0.565959  0.938298 -0.488098
# 1  -0.904615  1.607846 -0.858925
# 2   0.000982 -0.927009 -0.280384
# 3  -1.900124  0.695701  0.345090
# 4  -0.494950  0.396584  0.546067
# ..       ...       ...       ...
# 95 -1.626816 -1.660603 -0.170808
# 96 -1.097631  0.630780 -0.102535
# 97  0.340152  0.885809  0.395879
# 98 -0.066972 -0.047738 -0.778017
# 99  0.413979 -1.104727 -0.642853
#
# [100 rows x 3 columns]

# %%
df.dropna(axis='rows', thresh=3)    # 축을 기준으로 입력값이 3개 미만인 열 또는 행 삭제
# Out:
#            a         b         c   3
# 0   0.565959  0.938298 -0.488098 NaN
# 1  -0.904615  1.607846 -0.858925 NaN
# 2   0.000982 -0.927009 -0.280384 NaN
# 3  -1.900124  0.695701  0.345090 NaN
# 4  -0.494950  0.396584  0.546067 NaN
# ..       ...       ...       ...  ..
# 95 -1.626816 -1.660603 -0.170808 NaN
# 96 -1.097631  0.630780 -0.102535 NaN
# 97  0.340152  0.885809  0.395879 NaN
# 98 -0.066972 -0.047738 -0.778017 NaN
# 99  0.413979 -1.104727 -0.642853 NaN
#
# [100 rows x 4 columns]

# %%
s
# Out:
# 0         1
# 1         2
# 2       NaN
# 3    String
# 4      None
# dtype: object

# %%
s.fillna(0)
# Out:
# 0         1
# 1         2
# 2         0
# 3    String
# 4         0
# dtype: object

# %%
s.fillna(method='ffill')
# Out:
# 0         1
# 1         2
# 2         2
# 3    String
# 4    String
# dtype: object

# %%
s.fillna(method='bfill')
# Out:
# 0         1
# 1         2
# 2    String
# 3    String
# 4      None
# dtype: object

# %%
df
# Out:
#            a         b         c   3
# 0   0.565959  0.938298 -0.488098 NaN
# 1  -0.904615  1.607846 -0.858925 NaN
# 2   0.000982 -0.927009 -0.280384 NaN
# 3  -1.900124  0.695701  0.345090 NaN
# 4  -0.494950  0.396584  0.546067 NaN
# ..       ...       ...       ...  ..
# 95 -1.626816 -1.660603 -0.170808 NaN
# 96 -1.097631  0.630780 -0.102535 NaN
# 97  0.340152  0.885809  0.395879 NaN
# 98 -0.066972 -0.047738 -0.778017 NaN
# 99  0.413979 -1.104727 -0.642853 NaN
#
# [100 rows x 4 columns]

# %%
df.fillna(method='ffill', axis=0)
# Out:
#            a         b         c   3
# 0   0.565959  0.938298 -0.488098 NaN
# 1  -0.904615  1.607846 -0.858925 NaN
# 2   0.000982 -0.927009 -0.280384 NaN
# 3  -1.900124  0.695701  0.345090 NaN
# 4  -0.494950  0.396584  0.546067 NaN
# ..       ...       ...       ...  ..
# 95 -1.626816 -1.660603 -0.170808 NaN
# 96 -1.097631  0.630780 -0.102535 NaN
# 97  0.340152  0.885809  0.395879 NaN
# 98 -0.066972 -0.047738 -0.778017 NaN
# 99  0.413979 -1.104727 -0.642853 NaN
#
# [100 rows x 4 columns]

# %%
df.fillna(method='ffill', axis=1)
# Out:
#            a         b         c         3
# 0   0.565959  0.938298 -0.488098 -0.488098
# 1  -0.904615  1.607846 -0.858925 -0.858925
# 2   0.000982 -0.927009 -0.280384 -0.280384
# 3  -1.900124  0.695701  0.345090  0.345090
# 4  -0.494950  0.396584  0.546067  0.546067
# ..       ...       ...       ...       ...
# 95 -1.626816 -1.660603 -0.170808 -0.170808
# 96 -1.097631  0.630780 -0.102535 -0.102535
# 97  0.340152  0.885809  0.395879  0.395879
# 98 -0.066972 -0.047738 -0.778017 -0.778017
# 99  0.413979 -1.104727 -0.642853 -0.642853
#
# [100 rows x 4 columns]

# %%
df.fillna(method='bfill', axis=0)
# Out:
#            a         b         c   3
# 0   0.565959  0.938298 -0.488098 NaN
# 1  -0.904615  1.607846 -0.858925 NaN
# 2   0.000982 -0.927009 -0.280384 NaN
# 3  -1.900124  0.695701  0.345090 NaN
# 4  -0.494950  0.396584  0.546067 NaN
# ..       ...       ...       ...  ..
# 95 -1.626816 -1.660603 -0.170808 NaN
# 96 -1.097631  0.630780 -0.102535 NaN
# 97  0.340152  0.885809  0.395879 NaN
# 98 -0.066972 -0.047738 -0.778017 NaN
# 99  0.413979 -1.104727 -0.642853 NaN
#
# [100 rows x 4 columns]

# %%
df.fillna(method='bfill', axis=1)
# Out:
#            a         b         c   3
# 0   0.565959  0.938298 -0.488098 NaN
# 1  -0.904615  1.607846 -0.858925 NaN
# 2   0.000982 -0.927009 -0.280384 NaN
# 3  -1.900124  0.695701  0.345090 NaN
# 4  -0.494950  0.396584  0.546067 NaN
# ..       ...       ...       ...  ..
# 95 -1.626816 -1.660603 -0.170808 NaN
# 96 -1.097631  0.630780 -0.102535 NaN
# 97  0.340152  0.885809  0.395879 NaN
# 98 -0.066972 -0.047738 -0.778017 NaN
# 99  0.413979 -1.104727 -0.642853 NaN
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 중복 제거

# %%
df = pd.DataFrame({'c1':['a', 'b', 'c'] *2 + ['b'] + ['c'],
                   'c2':[1, 2, 1, 1, 2, 3, 3, 4]})
df
# Out:
#   c1  c2
# 0  a   1
# 1  b   2
# 2  c   1
# 3  a   1
# 4  b   2
# 5  c   3
# 6  b   3
# 7  c   4

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#   c1  c2
# 0  a   1
# 1  b   2
# 2  c   1
# 5  c   3
# 6  b   3
# 7  c   4

# %% [markdown]
# ### 값 치환

# %%
s = pd.Series([1., 2., -999., 3., -1000., 4.])
s
# Out:
# 0       1.0
# 1       2.0
# 2    -999.0
# 3       3.0
# 4   -1000.0
# 5       4.0
# dtype: float64

# %%
s.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       2.0
# 2       NaN
# 3       3.0
# 4   -1000.0
# 5       4.0
# dtype: float64

# %%
s.replace([-999, -1000], np.nan)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    3.0
# 4    NaN
# 5    4.0
# dtype: float64

# %%
s.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    3.0
# 4    0.0
# 5    4.0
# dtype: float64
