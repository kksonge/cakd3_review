# %% [markdown]
# ##### 딕셔너리의 모습

# %%
dic = {'naem':'pey', 'phone':'0119993323', 'birth':'1118'}

# %%
a = {1: 'hi'}

# %%
a = {'a', [1,2,3]}

# %% [markdown]
# ##### 딕셔너리 쌍 추가, 삭제하기

# %%
a = {1:'a'}
a[2]= 'b'
a
# Out:
# {1: 'a', 2: 'b'}

# %%
a['name'] = 'pey'
a
# Out:
# {1: 'a', 2: 'b', 'name': 'pey'}

# %%
a[3] = [1,2,3]
